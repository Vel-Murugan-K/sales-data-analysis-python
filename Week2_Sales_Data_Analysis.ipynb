# %% [markdown]
# <a href="https://colab.research.google.com/github/Vel-Murugan-K/sales-data-analysis-python/blob/main/Week2_Sales_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
from datetime import datetime, timedelta
products = [
    ("Laptop", "Electronics", 50000),
    ("Mobile", "Electronics", 20000),
    ("Headphones", "Electronics", 2000),
    ("Keyboard", "Accessories", 1500),
    ("Mouse", "Accessories", 800),
    ("Chair", "Furniture", 4000),
    ("Table", "Furniture", 6000),
    ("Notebook", "Stationery", 100),
    ("Pen", "Stationery", 20)
]

data = []

start_date = datetime(2025, 1, 1)

for i in range(1, 51):  # 50 records
    product, category, price = random.choice(products)
    quantity = random.randint(1, 5)
    order_date = start_date + timedelta(days=random.randint(0, 120))

    data.append([
        i,
        order_date.strftime("%Y-%m-%d"),
        product,
        category,
        quantity,
        price
    ])

columns = [
    "Order_ID",
    "Order_Date",
    "Product",
    "Category",
    "Quantity",
    "Price"
]

df = pd.DataFrame(data, columns=columns)
df["Total_Sales"] = df["Quantity"] * df["Price"]
total_revenue = df["Total_Sales"].sum()
total_orders = df["Order_ID"].count()

print("Overall Sales Summary")
print("----------------------")
print("Total Revenue:", total_revenue)
print("Total Orders:", total_orders)
product_sales = df.groupby("Product")["Total_Sales"].sum().reset_index()
print("\nProduct-wise Sales")
print(product_sales)
category_sales = df.groupby("Category")["Total_Sales"].sum().reset_index()
print("\nCategory-wise Sales")
print(category_sales)
df["Order_Date"] = pd.to_datetime(df["Order_Date"])
df["Month"] = df["Order_Date"].dt.month

monthly_sales = df.groupby("Month")["Total_Sales"].sum().reset_index()
print("\nMonthly Sales")
print(monthly_sales)

output_file = "week2_sales_analysis_output.csv"
df.to_csv(output_file, index=False)

print("\nFile exported successfully:", output_file)
# Out:
# Overall Sales Summary
# ----------------------
# Total Revenue: 1871300
# Total Orders: 50
#
# Product-wise Sales
#       Product  Total_Sales
# 0       Chair        52000
# 1  Headphones        26000
# 2    Keyboard        25500
# 3      Laptop       900000
# 4      Mobile       720000
# 5       Mouse         8000
# 6    Notebook         1700
# 7         Pen          100
# 8       Table       138000
#
# Category-wise Sales
#       Category  Total_Sales
# 0  Accessories        33500
# 1  Electronics      1646000
# 2    Furniture       190000
# 3   Stationery         1800
#
# Monthly Sales
#    Month  Total_Sales
# 0      1       325900
# 1      2       433800
# 2      3       655100
# 3      4       456500
#
# File exported successfully: week2_sales_analysis_output.csv
